# %% [markdown]
# **IMPORTING PACKAGE**

# %%
import cv2

# %% [markdown]
# **TO SHOW IMAGE IN GOOGLE COLLAB**

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# **TO READ AND SHOW IMAGE**

# %%
image = cv2.imread("images.png")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=212x238>

# %% [markdown]
# **TO SHOW IMAGE IN GRAY SCALE**

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=212x238>

# %% [markdown]
# **TO SHOW IMAGE IN INVERTED SCALE**

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=212x238>

# %% [markdown]
# **TO MAKE INVERTED IMAGE INTO BLUR**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=212x238>

# %% [markdown]
# **OUTPUT**

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=212x238>
# <PIL.Image.Image image mode=L size=212x238>

# %%
-
